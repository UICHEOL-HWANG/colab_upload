# %% [markdown]
# ## 딕셔너리(JSON) 사용하기
# * key : value 형태로 만들어진 자료형으로 반드시 key를 호출해야 value를 사용한다

# %% [markdown]
# ## 사용방법
# * {key : value } 형식

# %%
d = { '년월':202010, '국가':'대한민국', '방문자수':40000 }

# %%
d['년월']
# Out:
# 202010

# %%
d.items()
# Out:
# dict_items([('년월', 202010), ('국가', '대한민국'), ('방문자수', 40000)])

# %% [markdown]
# ## 2. 딕셔너리 key의 자료형
# * 문자열, 정수, 실수, 불린(True,False)
# * key로 올 수 없는 경우가 있는데 : list, 딕셔너리는 올수가 없음

# %%
x = {100:'hundred',False : 'asdasd' , 3.5 : [3.5,3.5]}

# %%
x[100]
# Out:
# 'hundred'

# %%
x[3.5]
# Out:
# [3.5, 3.5]

# %%
x[False]
# Out:
# 'asdasd'

# %%
x = {100:'hundred',100 : 'asdasd' , 3.5 : [3.5,3.5]}

# %%
x
# Out:
# {100: 'asdasd', 3.5: [3.5, 3.5]}

# %% [markdown]
# ### 3. 딕셔너리 값의 자료형
# * 딕셔너리 값에는 모든 자료형이 올 수 있다.
# *

# %%
y = {'정수':100,'실수':13.5,'문자열':'문자열문자열','리스트':[1,2,3,4],
     '튜플':(5,6,7,8),'딕셔너리':{'key':'value'},'boolean':True}

# %%
y.keys()
# Out:
# dict_keys(['정수', '실수', '문자열', '리스트', '튜플', '딕셔너리', 'boolean'])

# %% [markdown]
# ### 4.빈 딕셔너리 만들기
# * d = {}
# * d = dict()

# %%
d2 = dict()
d2
# Out:
# {}

# %% [markdown]
# ### 5. dict()로 딕셔너리 만들기
# * dict(key1 = value1 , key2 = value2) 형식으로 만들기
# * 주의할 점 : key 값에 '',""를 쓰면 안 된다.
# * 단점 : key 값에는 문자열로만 통일해서 넣을 수 있다 기존 {} 중괄호 내에서는 상관 없었지만 dict 내에서는 그게 불가능 하다는 것.

# %%
d = dict(정수 = 100 , 실수 = 13.5 , 리스트 =[1,2,3,4],딕셔너리 = {'딕셔너리':'허브'})

# %%
d
# Out:
# {'정수': 100, '실수': 13.5, '리스트': [1, 2, 3, 4], '딕셔너리': {'딕셔너리': '허브'}}

# %% [markdown]
# ### 2) dict([(key1,value1),(key2,value2)])
# * 리스트 안에 (key,value)의 튜플을 나열해서 만든다

# %%
d2 = dict([('정수',100),('실수',13.5)])
d2
# Out:
# {'정수': 100, '실수': 13.5}

# %% [markdown]
# ### 3) dict(zip([key1,key2,key3,value1,value2,value3~]))
# 형식으로 만들기
# * zip 함수를 사용하여 첫 번째 리스트 key로  두 번째 리스트를 value로 값을 매칭해서 합침
#
# dict(zip(['문자열','리스트','튜플','딕셔너리','블린']))

# %%
d3 = dict(zip(['문자열','리스트','튜플','딕셔너리','블린'],['딕셔너리의 값',[1,2,3,4],(5,6,7,8),{'key':'value'},True]))

# %%
d3
# Out:
# {'문자열': '딕셔너리의 값',
#  '리스트': [1, 2, 3, 4],
#  '튜플': (5, 6, 7, 8),
#  '딕셔너리': {'key': 'value'},
#  '블린': True}

# %%
d3['리스트'][2]
# Out:
# 3

# %%
d3['튜플'][3]
# Out:
# 8

# %%
d3['딕셔너리']['key']
# Out:
# 'value'

# %% [markdown]
# ### 딕셔너리 key와 value 값 삭제하기
# * del 변수명[key] : 삭제가능

# %%
del d3['문자열']

# %%
d3
# Out:
# {'리스트': [1, 2, 3, 4], '튜플': (5, 6, 7, 8), '딕셔너리': {'key': 'value'}, '블린': True}

# %% [markdown]
# ### 딕셔너리에 key와 value를 추가
# * 변수명[추가할 key] = 추가할 value

# %%
d3['문자열'] = '이것은 추가된 문자열 입니다.'

# %%
d3
# Out:
# {'리스트': [1, 2, 3, 4],
#  '튜플': (5, 6, 7, 8),
#  '딕셔너리': {'key': 'value'},
#  '블린': True,
#  '문자열': '이것은 추가된 문자열 입니다.'}

# %% [markdown]
# ### 딕셔너리의 key 확인여부 : in,not in 연산자 사용

# %%
'블린' in d3
# Out:
# True

# %%
'파이썬' in d3
# Out:
# False

# %% [markdown]
# ### 딕셔너리의 key 개수 구하기 : len(딕셔너리 변수명)
# * 주의할 점 : key의 개수를 구하는 것
# * 자료(value)의 개수가 아님

# %%
len(d2)
# Out:
# 2

# %%
len(d3)
# Out:
# 5

# %%
len(d3['리스트'])
# Out:
# 4

# %%
dic_list = {}

while True :
  key_input = input('key값 입력 >>')
  if key_input == 'q':
    break
  value_input = input('value값 입력 >>')
  dic_list[key_input]=value_input
# Out:
# key값 입력 >>aaa
# value값 입력 >>aaa
# key값 입력 >>q

# %%
dic_list
# Out:
# {'aaa': 'aaa'}
