# %%
import json

# %%
with open ('C:/Users/hi/Desktop/bigdata/data/전국치킨집리스트.json','r') as file :
    #  r"C:\Users\hi\Desktop\bigdata\data\전국치킨집리스트.json" 이렇게하면 역슬래시로도 가능
  dict_list = file.read()

# %%
print(type(dict_list))
# Out:
# <class 'str'>

# %%
chicken_info = json.loads(dict_list)

# %%
print(type(chicken_info))
# Out:
# <class 'list'>

# %%
len(chicken_info)
# Out:
# 37

# %%
chain_list = []

for i in chicken_info:
    for j in i['body']['items']:
        id =  j['bizesId']
        상호명 =  j['bizesNm']
        광역시명 =  j['ctprvnNm']
        시군구코드 =  j['signguCd']
        군구명 =  j['ldongNm']
        법정동코드 =  j['ldongCd']
        행정동코드 =  j['adongCd']
        지번주소 =  j['lnoAdr']
        도로명주소 =  j['rdnmAdr']
        층주소 =  j['flrNo']
        호수 =  j['hoNo']
        위도 =  j['lat']
        경도 =  j['lon']
        chain_list.append([id,상호명,광역시명,군구명,법정동코드,행정동코드,지번주소,도로명주소,층주소,호수,위도,경도])
        chicken_dict.append({"id":id,"상호명":상호명,"광역시명":광역시명,"군구명":군구명,"법정동코드":법정동코드,"행정동코드":행정동코드,"지번주소":지번주소,"도로명주소":도로명주소,"층주소":층주소,"호수":호수,"위도":위도,"경도":경도})

# %%
chain_list = []
keys_list = []
for i in chicken_info:
    for j in i['body']['items']:
        chain_list.append(j)

# %%
key_list = list(chicken_info[0]['header']['columns'])

# %%
key_list
# Out:
# ['상가업소번호',
#  '상호명',
#  '지점명',
#  '상권업종대분류코드',
#  '상권업종대분류명',
#  '상권업종중분류코드',
#  '상권업종중분류명',
#  '상권업종소분류코드',
#  '상권업종소분류명',
#  '표준산업분류코드',
#  '표준산업분류명',
#  '시도코드',
#  '시도명',
#  '시군구코드',
#  '시군구명',
#  '행정동코드',
#  '행정동명',
#  '법정동코드',
#  '법정동명',
#  'PNU코드',
#  '대지구분코드',
#  '대지구분명',
#  '지번본번지',
#  '지번부번지',
#  '지번주소',
#  '도로명코드',
#  '도로명',
#  '건물본번지',
#  '건물부번지',
#  '건물관리번호',
#  '건물명',
#  '도로명주소',
#  '구우편번호',
#  '신우편번호',
#  '동정보',
#  '층정보',
#  '호정보',
#  '경도',
#  '위도']

# %%
values_list
# Out:
# [['10027626',
#   '장모님치킨가창점',
#   '가창점',
#   'Q',
#   '음식',
#   'Q05',
#   '닭/오리요리',
#   'Q05A08',
#   '후라이드/양념치킨',
#   'I56193',
#   '치킨 전문점',
#   '27',
#   '대구광역시',
#   '27710',
#   '달성군',
#   '2771031000',
#   '가창면',
#   '2771031024',
#   '가창면',
#   '2771031024101200001',
#   '1',
#   '대지',
#   120,
#   1,
#   '대구광역시 달성군 가창면 냉천리 120-1',
#   '277103148001',
#   '대구광역시 달성군 가창면 가창동로',
#   6,
#   '',
#   '2771031024101200004036858',
#   '',
#   '대구광역시 달성군 가창면 가창동로 6',
#   '711861',
#   '42938',
#   '',
#   '1',
#   '',
#   128.644458591419,
#   35.7826625402814],
#  ['10098244',
#   '짱구피자치킨',
#   '',
#   'Q',
#   '음식',
#   'Q05',
#   '닭/오리요리',
#   'Q05A08',
#   '후라이드/양념치킨',
#   'I56193',
#   '치킨 전문점',
#   '41',
#   '경기도',
#   '41250',
#   '동두천시',
#   '4125056500',
#   '불현동',
#   '4125010300',
#   '생연동',
#   '4125010300102680011',
#   '1',
#   '대지',
#   268,
#   11,
#   '경기도 동두천시 생연동 268-11',
#   '412503189006',
#   '경기도 동두천시 못골로',
#   30,
#   '',
#   '4125010300102680011008557',
# ...

# %%
values_list = []
for i in chain_list:
    values_list.append(list(i.values()))

# %%
with open("dict.csv", 'w') as file:
    header = ["id","상호명","광역시명","군구명","법정동코드","행정동코드","지번주소","도로명주소","층주소","호수","위도","경도"]
    writer = csv.DictWriter(file, fieldnames=header)
    writer.writeheader()

    for element in chicken_dict:
        writer.writerow(element)

# %%
import csv

with open('chickenList.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    # 컬럼명 추가
    writer.writerow(key_list)
    
    # 값들 추가
    writer.writerows(values_list)

# %%
#딕셔너리와 함수를 사용한 언패킹

# %%
with open ('C:/Users/hi/Desktop/bigdata/data/전국치킨집리스트.json','r') as file :
    #  r"C:\Users\hi\Desktop\bigdata\data\전국치킨집리스트.json" 이렇게하면 역슬래시로도 가능
  data = file.read()

# %%
data = json.loads(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 data = json.loads(data)
#
# File c:\Users\hi\anaconda3\envs\myvenv\lib\json\__init__.py:341, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     339 else:
#     340     if not isinstance(s, (bytes, bytearray)):
# --> 341         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     342                         f'not {s.__class__.__name__}')
#     343     s = s.decode(detect_encoding(s), 'surrogatepass')
#     345 if "encoding" in kw:
#
# TypeError: the JSON object must be str, bytes or bytearray, not list

# %%
type(data)
# Out:
# list

# %%
for shops in data:
    for shop in shops['body']['items']:
        temp = list(shop.values())
        temp2 = list(shop.keys())

# %%
temp
# Out:
# ['9967953',
#  '웰빙치킨',
#  '',
#  'Q',
#  '음식',
#  'Q05',
#  '닭/오리요리',
#  'Q05A08',
#  '후라이드/양념치킨',
#  'I56193',
#  '치킨 전문점',
#  '42',
#  '강원도',
#  '42130',
#  '원주시',
#  '4213060000',
#  '우산동',
#  '4213011100',
#  '우산동',
#  '4213011100101360002',
#  '1',
#  '대지',
#  136,
#  2,
#  '강원도 원주시 우산동 136-2',
#  '421304457330',
#  '강원도 원주시 상지대길',
#  43,
#  '',
#  '4213011100101360002016167',
#  '',
#  '강원도 원주시 상지대길 43',
#  '220954',
#  '26342',
#  '',
#  '1',
#  '',
#  127.9372901421,
#  37.3695910222738]

# %%
import pandas as pd 

df = pd.read_csv('C:/Users/hi/Desktop/bigdata/치킨집 parser - 시트1.csv',encoding='utf-8')

# %%
df.head()
# Out:
#          id         상호명   광역시명  군구명       법정동코드       행정동코드  \
# 0  10027626    장모님치킨가창점  대구광역시  가창면  2771031024  2771031000
# 1  11928045  또봉이통닭동산남부점   전라북도  동산동  4514011100  4514057000
# 2  12078378        맘스터치  광주광역시  장덕동  2920012300  2920063700
# 3  12448730        굽네치킨  인천광역시  강화읍  2871025025  2871025000
# 4  12603882       60계치킨  부산광역시  광안동  2650010400  2650077000
#
#                       지번주소                   도로명주소 층주소         위도          경도
# 0  대구광역시 달성군 가창면 냉천리 120-1    대구광역시 달성군 가창면 가창동로 6   1  35.782663  128.644459
# 1      전라북도 익산시 동산동 609-31      전라북도 익산시 평동로12길 21   1  35.927144  126.958748
# 2       광주광역시 광산구 장덕동 1675   광주광역시 광산구 풍영로200번길 63   1  35.189873  126.817747
# 3  인천광역시 강화군 강화읍 갑곳리 648-5  인천광역시 강화군 강화읍 강화대로 199   1  37.740269  126.506778
# 4     부산광역시 수영구 광안동 190-19   부산광역시 수영구 남천바다로21번길 6   1  35.149334  129.113234

# %%
df[df['상호명'] == '60계치킨']
# Out:
#              id    상호명   광역시명   군구명       법정동코드       행정동코드  \
# 4      12603882  60계치킨  부산광역시   광안동  2650010400  2650077000
# 351    11776170  60계치킨   경상북도   형곡동  4719010900  4719058200
# 1414   11982590  60계치킨  인천광역시   삼산동  2823710500  2823764600
# 2016   12075650  60계치킨  울산광역시   범서읍  3171025922  3171025900
# 2022   12076740  60계치킨  울산광역시   천곡동  3120010800  3120053000
# ...         ...    ...    ...   ...         ...         ...
# 18447  18225009  60계치킨   전라북도   수송동  4513014100  4513069000
# 18492  18235158  60계치킨   충청남도   서천읍  4477025321  4477025300
# 18564  18251779  60계치킨    강원도  주문진읍  4215025021  4215025000
# 18608  18259789  60계치킨    경기도   화정동  4128112300  4128162100
# 18943  18332645  60계치킨   전라남도   해룡면  4615031022  4615031000
#
#                           지번주소                    도로명주소  층주소         위도  \
# 4         부산광역시 수영구 광안동 190-19    부산광역시 수영구 남천바다로21번길 6    1  35.149334
# 351         경상북도 구미시 형곡동 146-7        경상북도 구미시 형곡동로 103    1  36.111497
# ...

# %%
dict_list = json.loads(dict_list)

# %%
df = pd.json_normalize(dict_list[0]['body']['items'])

# %%
df
# Out:
#       bizesId     bizesNm brchNm indsLclsCd indsLclsNm indsMclsCd indsMclsNm  \
# 0    10027626    장모님치킨가창점    가창점          Q         음식        Q05     닭/오리요리
# 1    10098244      짱구피자치킨                 Q         음식        Q05     닭/오리요리
# 2    10099459        쭈노치킨                 Q         음식        Q05     닭/오리요리
# 3    10136167        치킨뱅이                 Q         음식        Q05     닭/오리요리
# 4    10136346     치킨월드율량점    율량점          Q         음식        Q05     닭/오리요리
# ..        ...         ...    ...        ...        ...        ...        ...
# 995  11927120     두두두마리치킨                 Q         음식        Q05     닭/오리요리
# 996  11927310    호식이두마리치킨                 Q         음식        Q05     닭/오리요리
# 997  11927491       또봉이치킨                 Q         음식        Q05     닭/오리요리
# 998  11927616  투마리치킨하늘도시점  하늘도시점          Q         음식        Q05     닭/오리요리
# 999  11927757        노랑통닭  구리수택점          Q         음식        Q05     닭/오리요리
#
# ...

# %%
result = pd.DataFrame() 

for item in data:
    temp = pd.DataFrame(item['body']['items'])
    result = pd.concat([result,temp])

# %%
result
# Out:
#      bizesId    bizesNm brchNm indsLclsCd indsLclsNm indsMclsCd indsMclsNm  \
# 0   10027626   장모님치킨가창점    가창점          Q         음식        Q05     닭/오리요리
# 1   10098244     짱구피자치킨                 Q         음식        Q05     닭/오리요리
# 2   10099459       쭈노치킨                 Q         음식        Q05     닭/오리요리
# 3   10136167       치킨뱅이                 Q         음식        Q05     닭/오리요리
# 4   10136346    치킨월드율량점    율량점          Q         음식        Q05     닭/오리요리
# ..       ...        ...    ...        ...        ...        ...        ...
# 59   9829515       아리치킨                 Q         음식        Q05     닭/오리요리
# 60   9851302       애니치킨                 Q         음식        Q05     닭/오리요리
# 61   9867543      에디슨치킨                 Q         음식        Q05     닭/오리요리
# 62   9918905  오븐에꾸운닭장유점    장유점          Q         음식        Q05     닭/오리요리
# 63   9967953       웰빙치킨                 Q         음식        Q05     닭/오리요리
#
# ...

# %%
result.to_csv('전국치킨집정보.csv',encoding='utf-8')
