# %% [markdown]
# ### 조건문
#
# * 사용방법
# ``` python
#  if # 조건식 :
#   # 코드  (조건식이 참일 때)
# elif #조건식 :
#   # 다른코드 (다른 조건이 참일 때)
# else :
#   # 나머지 조건들 (조건식이 거짓일 때)
# ```

# %%
x = 11

# %%
if x == 10 :
  print("참")
else:
  print("거짓")
# Out:
# 거짓

# %%
L1 = ['파이썬','조건문',10,15.3,True,[1,2,3],(1,2,3),{'key':'value'}]

# %%
if '조건문' in L1:
  print('들어있다')
else:
  print('없다')
# Out:
# 들어있다

# %% [markdown]
# ### 값을 입력 받아 홀수인지 짝수인지 판단하는 프로그램

# %%
x = int(input(' 값 입력 >> '))

if x%2 ==0 :
  print('짝수')
else :
  print('홀수')
# Out:
#  값 입력 >> 18
# 짝수

# %% [markdown]
# ### 다중 조건문 사용
# * elif
#
# ```python
#
# if # 조건문 :
#   # 코드 ( 조건이 참일 때 실행 )
# elif # 조건문2 :
#   # 코드 ( 조건2가 참일 때 )
# elif # 조건문3 :
#   # 코드 ( 조건3가 참일 때 )
# else :
#   # 조건이 거짓일 때
# ```

# %%
# 학점 판별기 만들자

# %% [markdown]
# ### 학점 판별 프로그램
# * 81-100 : A <BR>
# 61-80 : B <BR>
# 41-60 : C <BR>
# 21-40 : D <BR>
# 0 - 20 : F <BR>

# %%
while True:
  user_input = int(input('점수 입력 >> '))

  if (80 < user_input<=100):
    print('A')
    break
  elif (60 < user_input <= 80):
    print('B')
    break
  elif (40 < user_input <= 60):
    print('C')
    break
  elif(20< user_input <= 40):
    print('D')
    break
  elif(0<= user_input <= 20):
    print('F')
    break
  else:
    print("없는 점수입니다 다시 입력해주세요")
    continue
# Out:
# 점수 입력 >> -505
# 없는 점수입니다 다시 입력해주세요
# 점수 입력 >> 213131
# 없는 점수입니다 다시 입력해주세요
# 점수 입력 >> -8000
# 없는 점수입니다 다시 입력해주세요
# 점수 입력 >> 100
# A

# %% [markdown]
# ### 교통비 차감 프로그램
# 표준 입력으로 나이(만 나이)가 입력 됩니다 (입력 값은 7 이상 입력됨 ) <br>
# 교통카드 시스템에서 시내버스 요금은 다음과 같으며 , 각 나이에 맞게 요금을 차감한 뒤 잔액이 출력되게 만드시오 (if,elif사용)
#
# 현재 교통카드에는 9,000원이 들어 있습니다<br>
# 어린이 650원 (7세 이상 12세 이하)  <br>
# 청소년 1,050원 (13세 이상 18세 이하) <br>
# 어른 (19세 이상) 1,250원

# %%
# 입력 받는 곳
# 나이가 7살 이상이면 판별
# 나이가 7살 이상이면 어린이,청소년,어른별로 교통카드에서 요금 차감

pay = 9000
user_age = int(input('나이를 입력하세요 >> '))


if 0 <= user_age <= 100:
  if (7<=user_age<=12 ):
    print(f'잔액은 {pay-650}원 입니다')
  elif (13<= user_age <=18):
    print(f'잔액은 {pay-1050}원 입니다')
  elif user_age >= 20 :
    print(f'잔액은 {pay-1250}원 입니다')
  elif (0<= user_age<=11):
    print('미취학 아동은 무료입니다')
else :
  print('없는 범위 입니다 : -살, 100살 넘어가면 지구인이 아니야')
# Out:
# 나이를 입력하세요 >> -10
# 없는 범위 입니다 : -살, 100살 넘어가면 지구인이 아니야

# %% [markdown]
# ### 파이썬 만의 if 조건문 작성방법
#
# ```python
#
# # 참일 때 입력할 값
# if # 조건문 else # 거짓일 때 입력할 값
#
# ```

# %%
a = int(input())
b = int(input())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-075d7e1f80b2> in <cell line: 1>()
# ----> 1 a = int(input())
#       2 b = int(input())
#       3
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
if a == b :
  print(f'{a}와 {b}가 같다')
else :
  print(False)
# Out:
# 1와 1가 같다

# %%
True if a == b else False
# pythonic 스러운 if문
# Out:
# True
